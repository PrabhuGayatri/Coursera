# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# My Jupyter Notebook

# %% [markdown]
# **Gayatri Prabhu**
# <br>Undergraduate <br>

# %% [markdown]
# *I am interested in data science because it is one of the latest technologies that can be helpful for the world.*

# %% [markdown]
# ### The following code prints the name of the course.

# %%
print("This is the tools for data science course")
# Out:
# This is the tools for data science course

# %% [markdown]
#  1. The numbered list 1
#     1. Numbered sublist 1
#     2. Numbered sublist 2
# - Main bullet point
#     - Sub bullet point 1
#     - Sub bullet point 2
#
# <br>*** This is a horizontal line.<br>
#
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
